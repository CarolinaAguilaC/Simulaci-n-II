# %% [markdown]
# # Uso de los números aleatorios

# %% [markdown]
# ## 1. Introducción al Módulo random

# %% [markdown]
# El módulo random de la librería estándar de Python incluye un conjunto de funciones que permiten obtener de distintos modos
# números pseudoaleatorios a través del algoritmo [Mersenne Twister](https://es.wikipedia.org/wiki/Mersenne_twister).

# %%
#importamos el módulo que vamos a usar

import random

# %% [markdown]
# Las funciones de los módulos se invocan con el formato: módulo.función().
#
# En el módulo random existe la función random, que devuelve un número aleatorio que sigue una distribución uniforme.
#
# Así, para obtener $x \sim U(0,1)$:

# %%
x = random.random()  #Cada ejecución dará un número distinto.
print(x)
# Out:
# 0.4412419592206156

# %% [markdown]
# Se puede usar algún bucle si se desea generar una secuencia $x_i \sim U(0,1)$ con $i = 1, 2, 3,..., N$:

# %%
for i in range(10):
    print('%05.4f' % random.random(), end=' ')  #El código en rojo indica la cantidad de dígitos y de decimales a mostrar.
print()
# Out:
# 0.2866 0.5120 0.9110 0.8184 0.8071 0.6004 0.0335 0.6162 0.3664 0.5765

# %%
for i in range(10):
    print('%05.4f' % random.random(), sep="\t")
print()
# Out:
# 0.0124
# 0.7570
# 0.3008
# 0.5743
# 0.2440
# 0.2467
# 0.2890
# 0.7923
# 0.7034
# 0.5650

# %% [markdown]
# La función seed() fija el valor de la semilla en la generación de la secuencia de números aleatorios.
# Esto es útil cuando se quieren utilizar los mismos datos de entrada en una simulación.

# %%
random.seed(1) #primero fijamos la semilla

for i in range(20):
    print('%05.4f' % random.random(), end=' ')
print()
# Out:
# 0.1344 0.8474 0.7638 0.2551 0.4954 0.4495 0.6516 0.7887 0.0939 0.0283 0.8358 0.4328 0.7623 0.0021 0.4454 0.7215 0.2288 0.9453 0.9014 0.0306

# %% [markdown]
# ## Ejercicio 1:
#     a)Usar la función random() para simular 1 volado.
#     b)Usar la función random() para simular 1000 volados.
#     c)Determinar de b) la probabilidad de que ocurra "sol" en un volado.

# %%
import random

# Simulación de un volado
resultado = "sol" if random.random() <= 0.5 else "águila"

# Imprimir el resultado
print("El resultado del volado es:", resultado)
# Out:
# El resultado del volado es: águila

# %%
import random

# Simulación de 1000 volados
resultados = []
for _ in range(1000):
    resultado = "sol" if random.random() <= 0.5 else "águila"
    resultados.append(resultado)

# Imprimir los resultados
print("Resultados de los 1000 volados:", resultados)
# Out:
# Resultados de los 1000 volados: ['sol', 'águila', 'águila', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'águila', 'águila', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'águila', 'águila', 'sol', 'águila', 'águila', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'sol', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'águila', 'águila', 'águila', 'águila', 'sol', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'águila', 'sol', 'águila', 'águila', 'águila', 'águila', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'águila', 'sol', 'águila', 'sol', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 
'sol', 'águila', 'águila', 'águila', 'águila', 'sol', 'águila', 'águila', 'sol', 'águila', 'sol', 'sol', 'sol', 'sol', 'águila', 'águila', 'sol', 'águila', 'sol', 'sol', 'sol', 'sol', 'águila', 'sol', 'sol', 'sol', 'sol', 'águila', 'águila', 'águila', 'sol', 'sol', 'águila', 'sol', 'águila', 'sol', 'águila', 'águila', 'águila', 'águila', 'águila', 'sol', 'águila', 'águila', 'águ ...

# %%
import random

# Simulación de 1000 volados
resultados = []
for _ in range(1000):
    resultado = "sol" if random.random() <= 0.5 else "águila"
    resultados.append(resultado)

# Calcular la probabilidad de "sol"
contador_sol = resultados.count("sol")
probabilidad_sol = contador_sol / len(resultados)

# Imprimir la probabilidad
print("Probabilidad de que ocurra 'sol' en un volado:", probabilidad_sol)
# Out:
# Probabilidad de que ocurra 'sol' en un volado: 0.502

# %% [markdown]
# La función uniform() devuelve un número float incluido entre los valores indicados.

# %%
for i in range(10):
    print('%5.4f' %random.uniform(1, 50), end=' ')
print()
# Out:
# 38.3983 25.7376 23.5307 2.2455 24.4919 35.8450 44.9780 11.5344 27.2356 12.0078

# %% [markdown]
# La función randint() devuelve un número entero incluido entre los valores indicados.
# Los valores de los límites inferior y superior también pueden aparecer entre los valores devueltos.

# %%
for i in range(20):
    print(random.randint(-100, 100), end=' ')
print()
# Out:
# 50 -58 24 87 -81 82 96 12 55 -75 82 -44 -37 88 57 -80 44 28 11 -100

# %% [markdown]
# ## Ejercicio 2:
#     a) Simular un sorteo de los colores blanco, negro, rojo, azul y verde.
#     b) Simular 5 sorteos con sustitución.

# %%
import random

# Colores posibles
colores = ["blanco", "negro", "rojo", "azul", "verde"]

# Simulación de un sorteo
color_seleccionado = random.choice(colores)

# Imprimir el resultado
print("El color seleccionado es:", color_seleccionado)
# Out:
# El color seleccionado es: verde

# %%
import random

# Colores posibles
colores = ["blanco", "negro", "rojo", "azul", "verde"]

# Simulación de 5 sorteos con sustitución
sorteos = []
for _ in range(5):
    color_seleccionado = random.choice(colores)
    sorteos.append(color_seleccionado)

# Imprimir los resultados
print("Resultados de los 5 sorteos con sustitución:", sorteos)
# Out:
# Resultados de los 5 sorteos con sustitución: ['blanco', 'negro', 'azul', 'verde', 'azul']

# %% [markdown]
# La función randrange() devuelve enteros que van desde un valor inicial a otro final
# separados entre sí un número de valores determinados.

# %%
for i in range(20):
    print(random.randrange(0, 20, 3), end=' ')
print()
# Out:
# 0 12 15 9 9 9 15 15 3 0 0 6 0 3 0 12 3 3 3 0

# %% [markdown]
# # 2. Estimación del número $\pi$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 100)
y = np.sqrt(1 - x**2)               # Ecuación del círculo en el primer cuadrante


x_1 = random.random()
y_1 = random.random()

fig = plt.figure(1, figsize=(8, 8))        # Aquí fijamos el formato de la gráfica para que sea cuadrada.
plt.plot(x, y, color="red", markersize=1)
plt.scatter(x_1, y_1, s=20, c="blue")
plt.title("Estimación de $\pi$")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %% [markdown]
# # Tarea 1.
#     Estimar el valor de pi usando la función random

# %%
import random

# Número de puntos a generar
num_puntos = 1000000

# Contador de puntos dentro del círculo
num_puntos_dentro = 0

# Generar puntos aleatorios y contar los que están dentro del círculo
for _ in range(num_puntos):
    x = random.random()  # Coordenada x aleatoria en el rango [0, 1]
    y = random.random()  # Coordenada y aleatoria en el rango [0, 1]
    distancia = x**2 + y**2  # Distancia al origen (0, 0)
    if distancia <= 1:  # Si el punto está dentro del círculo
        num_puntos_dentro += 1

# Calcular la estimación de pi
estimacion_pi = 4 * num_puntos_dentro / num_puntos

# Imprimir la estimación de pi
print("Estimación de pi:", estimacion_pi)
# Out:
# Estimación de pi: 3.144584

# %% [markdown]
# ## La aproximación analítica

# %% [markdown]
# Partamos de la ecuación:
#
# ##     $\pi = 4\arctan 1$
#
# y usemos la aproximación de Taylor para expandir en una serie de potencias.
#
# Recordar:
#
# $f(x) = f(0) + f´(x)x + \frac{1}{2}f´´(0)x^2 + ...$
#
# $Si f(x) = \arctan x$ entonces:
#
# $f´(x) = \frac{d \arctan x}{dx} = \frac{1}{1 + x^2} \rightarrow f´(0) = 1$
#
# $f´´(x) = \frac{d^2 \arctan x}{d^2x} = - \frac{2x}{(1 + x^2)^2} \rightarrow f´´(0) = 0$
#
# ...
#
# $f^{2i + 1}(x) = (-1)^{i} \frac{(2i)!}{(1 + x^2)^{2i + 1}} \rightarrow f^{2i + 1}(0) = (-1)(2i)!$
#
# $f^{2i}(x) = 0$
#
# Entonces:
#
# $\arctan x = \sum_{i = 0} (-1)^{i} \frac{x^{2i + 1}}{2i + 1}$
#
# Por tanto:
#
# ## $\pi = \sum_{i = 0} (-1)^{i} \frac{4}{2i + 1}$

# %%
def pi_taylor(n):
    pi = 0
    for i in range(n):
        pi = pi + 4.0/(2*i+1)*(-1)**i
        print(i, pi)

# %%
pi_taylor(10)
# Out:
# 0 4.0
# 1 2.666666666666667
# 2 3.466666666666667
# 3 2.8952380952380956
# 4 3.3396825396825403
# 5 2.9760461760461765
# 6 3.2837384837384844
# 7 3.017071817071818
# 8 3.2523659347188767
# 9 3.0418396189294032

# %%
def pi_Taylor(n):
    pi = 0
    L =[]
    for i in range(n):
        pi = pi + 4.0/(2*i+1)*(-1)**i
        L.append(pi)
    fig = plt.figure(1, figsize=(8, 8))
    plt.plot(L, color="red", markersize=1)
    plt.xlabel("Iteraciones")
    plt.ylabel("Estimación")
    plt.grid()
    plt.show()

# %%
pi_Taylor(200)

# %% [markdown]
# ## Ejercicio 3:
#
# Graficar las salidas obtenidas en la Tarea 1

# %%
import random
import matplotlib.pyplot as plt

# Número de puntos a generar
num_puntos = 1000000

# Contador de puntos dentro del círculo
num_puntos_dentro = 0

# Coordenadas de los puntos dentro y fuera del círculo
coord_x_dentro = []
coord_y_dentro = []
coord_x_fuera = []
coord_y_fuera = []

# Generar puntos aleatorios y contar los que están dentro del círculo
for _ in range(num_puntos):
    x = random.random()  # Coordenada x aleatoria en el rango [0, 1]
    y = random.random()  # Coordenada y aleatoria en el rango [0, 1]
    distancia = x**2 + y**2  # Distancia al origen (0, 0)

    if distancia <= 1:  # Si el punto está dentro del círculo
        num_puntos_dentro += 1
        coord_x_dentro.append(x)
        coord_y_dentro.append(y)
    else:
        coord_x_fuera.append(x)
        coord_y_fuera.append(y)

# Calcular la estimación de pi
estimacion_pi = 4 * num_puntos_dentro / num_puntos

# Crear figura y ejes
fig, ax = plt.subplots()

# Graficar los puntos dentro y fuera del círculo
ax.scatter(coord_x_dentro, coord_y_dentro, color='blue', label='Dentro del círculo')
ax.scatter(coord_x_fuera, coord_y_fuera, color='red', label='Fuera del círculo')

# Configurar aspecto del gráfico
ax.set_aspect('equal')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_title('Estimación de pi: {}'.format(estimacion_pi))
ax.legend()

# Mostrar el gráfico
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Continuamos

# %%
x = np.linspace(0, 1, 100)
y = np.sqrt(1 - x**2)               # Ecuación del círculo en el primer cuadrante


x_1 = random.random()
y_1 = random.random()

fig = plt.figure(1, figsize=(8, 8))        # Aquí fijamos el formato de la gráfica para que sea cuadrada.
plt.plot(x, y, color="red", markersize=1)
plt.scatter(x_1, y_1, s=20, c="blue")
plt.title("Estimación de $\pi$")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %%
def pi_mc(n):
    pi = 0
    counter = 0
    for i in range(n):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <1:
            counter = counter + 1
        pi = 4.0*float(counter)/(i + 1)
        print(i, pi)

# %%
pi_mc(10)
# Out:
# 0 4.0
# 1 2.0
# 2 2.6666666666666665
# 3 3.0
# 4 3.2
# 5 3.3333333333333335
# 6 2.857142857142857
# 7 3.0
# 8 3.111111111111111
# 9 3.2

# %%
def pi_mc(n):
    pi = 0
    lx = []
    ly = []
    counter = 0
    for i in range(n):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <1:
            counter = counter + 1
            lx.append(counter)
            ly.append(4.0*float(counter)/(i + 1))

        pi = 4.0*float(counter)/(i + 1)

        e = np.absolute((pi - np.pi)/np.pi)
    print("pi =", pi)
    print("error =", e)

    fig = plt.figure(1, figsize=(8, 8))
    plt.xlabel("Iteraciones")
    plt.ylabel("Estimación de $\pi$")
    plt.grid()
    plt.plot(lx, ly, color="blue", markersize=1)
    plt.show()

# %%
pi_mc(1000)
# Out:
# pi = 3.1
# error = 0.013239352830248852

# %% [markdown]
# Si se tiene, para cada punto aleatorio:
#
# $X_i = 1$ si cae dentro del circulo y
#
# $X_i = 0$ si cae fuera

# %% [markdown]
# ## Ejercicio 4:
#
# a) Calcular $E[X_i]$ y $V[X_i]$

# %% [markdown]
# Para el experimento de simulación, definimos $Z_N = \frac{X_1 + X_2 + ... + X_N}{N}$

# %% [markdown]
# ## Ejercicio 5:
# a) Calcular  $E[Z_N]$ y $V[Z_N]$
# b) ¿Cuál debe ser el valor de $N$ para que el error sea de 0.01?

# %% [markdown]
# # Integrales

# %%
def riemannplot(f, a, b, ra, rb, n):
    # f es la función
    # a y b son los limites del eje x para graficar la funcion f
    # ra y rb son los limites del intervalo en el eje x del que queremos calcular la suma
    # n es el numero de rectangulos que calcularemos

    atenuacion = (b-a)/100
    x = np.arange(a, b+atenuacion, atenuacion)

    plt.plot(x, f(x), color='red')

    delta_x = (rb-ra)/n
    riemannx = np.arange(ra, rb, delta_x)
    riemanny = f(riemannx)
    riemann_sum = sum(riemanny*delta_x)

    plt.bar(riemannx,riemanny,width=delta_x,alpha=0.5,edgecolor = 'black',facecolor='green')

    plt.xlabel('x')
    plt.ylabel('f(x)')

    plt.title('Suma de Riemann por la izquierda de f(x)')
    plt.figtext(0.1,-0.05, "Suma de Riemann: %.5f " %(riemann_sum), color='b')
    plt.savefig('riemann.png')
    plt.show()

# %%
def f(x):
    return np.sqrt(np.arctan(x))

# %%
riemannplot(f, 0, 1.001, 0, 1.001, 20)
